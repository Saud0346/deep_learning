# %%
import pandas as pd
import numpy as np
import sklearn.datasets
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler

# %%
data = sklearn.datasets.load_breast_cancer()
#converting to dataframe
labels = pd.DataFrame(data.target)
data   =   pd.DataFrame(data.data,columns = data.feature_names)

# %%
print(data)
print(labels)

# %%
data.describe()

# %%
data.isnull().sum()

# %%
data.info()

# %%
data.columns

# %%
labels.isnull().sum()

# %%
labels.info()

# %%
labels.describe()

# %%
labels.value_counts()

# %%
X_train, X_test, Y_train, Y_test =train_test_split(data,labels, test_size=0.2, random_state=2)

# %%
print(X_train.shape,X_test.shape,Y_train.shape,Y_test.shape)

# %% [markdown]
# # Now Making Neural network

# %%
import tensorflow as tf
tf.random.set_seed(3)
from tensorflow import keras
# Out:
# 2024-07-22 14:23:46.579324: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
model = keras.Sequential([
                          keras.layers.Flatten(input_shape = (30,)),
                          keras.layers.Dense(100,activation = 'relu'),
                          keras.layers.Dense(200,activation = 'sigmoid'),
                          keras.layers.Dense(100,activation = 'relu'),
                          keras.layers.Dense(2,activation  = 'sigmoid')
])

# %%
#compiling the model
model.compile(optimizer='adam', 
              loss='sparse_categorical_crossentropy', 
              metrics=['accuracy'])

# %%
history = model.fit(X_train, Y_train, validation_split=0.1, epochs=20)
# Out:
# Epoch 1/20
# 13/13 [==============================] - 0s 8ms/step - loss: 2.0591 - accuracy: 0.8093 - val_loss: 1.1382 - val_accuracy: 0.8478
# Epoch 2/20
# 13/13 [==============================] - 0s 3ms/step - loss: 1.9885 - accuracy: 0.8093 - val_loss: 1.0976 - val_accuracy: 0.8696
# Epoch 3/20
# 13/13 [==============================] - 0s 3ms/step - loss: 1.9168 - accuracy: 0.8068 - val_loss: 1.1722 - val_accuracy: 0.8043
# Epoch 4/20
# 13/13 [==============================] - 0s 3ms/step - loss: 1.8335 - accuracy: 0.8142 - val_loss: 1.0096 - val_accuracy: 0.8696
# Epoch 5/20
# 13/13 [==============================] - 0s 3ms/step - loss: 1.7762 - accuracy: 0.8264 - val_loss: 1.0866 - val_accuracy: 0.8478
# Epoch 6/20
# 13/13 [==============================] - 0s 3ms/step - loss: 1.7791 - accuracy: 0.8068 - val_loss: 0.9642 - val_accuracy: 0.8696
# Epoch 7/20
# 13/13 [==============================] - 0s 3ms/step - loss: 1.6562 - accuracy: 0.8191 - val_loss: 1.0113 - val_accuracy: 0.8478
# Epoch 8/20
# 13/13 [==============================] - 0s 3ms/step - loss: 1.6216 - accuracy: 0.8337 - val_loss: 0.9113 - val_accuracy: 0.8696
# Epoch 9/20
# 13/13 [==============================] - 0s 3ms/step - loss: 1.5585 - accuracy: 0.8289 - val_loss: 0.9565 - val_accuracy: 0.8478
# Epoch 10/20
# 13/13 [==============================] - 0s 3ms/step - loss: 1.5350 - accuracy: 0.8362 - val_loss: 0.9048 - val_accuracy: 0.8478
# Epoch 11/20
# 13/13 [==============================] - 0s 3ms/step - loss: 1.4670 - accuracy: 0.8435 - val_loss: 0.7994 - val_accuracy: 0.8696
# Epoch 12/20
# 13/13 [==============================] - 0s 4ms/step - loss: 1.4393 - accuracy: 0.8289 - val_loss: 0.9011 - val_accuracy: 0.8478
# Epoch 13/20
# 13/13 [==============================] - 0s 3ms/step - loss: 1.3633 - accuracy: 0.8411 - val_loss: 0.7608 - val_accuracy: 0.8696
# Epoch 14/20
# 13/13 [==============================] - 0s 3ms/step - loss: 1.4205 - accuracy: 0.8655 - val_loss: 0.8404 - val_accuracy: 0.8478
# Epoch 15/20
# 13/13 [==============================] - 0s 4ms/step - loss: 1.3202 - accuracy: 0.8386 - val_loss: 0.8309 - val_accuracy: 0.8478
# Epoch 16/20
# 13/13 [==============================] - 0s 3ms/step - loss: 1.2994 - accuracy: 0.8631 - val_loss: 0.6993 - val_accuracy: 0.8913
# Epoch 17/20
# 13/13 [==============================] - 0s 3ms/step - loss: 1.2216 - accuracy: 0.8533 - val_loss: 0.7571 - val_accuracy: 0.8478
# Epoch 18/20
# 13/13 [==============================] - 0s 3ms/step - loss: 1.2229 - accuracy: 0.8484 - val_loss: 0.7126 - val_accuracy: 0.8478
# Epoch 19/20
# 13/13 [==============================] - 0s 3ms/step - loss: 1.1725 - accuracy: 0.8631 - val_loss: 0.6495 - val_accuracy: 0.8913
# Epoch 20/20
# 13/13 [==============================] - 0s 3ms/step - loss: 1.1667 - accuracy: 0.8680 - val_loss: 0.6625 - val_accuracy: 0.8913

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])

plt.title('Model Accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')

plt.legend(['training data','validation data'], loc = 'lower right')

# %% [markdown]
# # Now lets Standarize the data to improve the accuracy

# %%
scaler = StandardScaler()
std_train = scaler.fit_transform(X_train)
std_test = scaler.transform(X_test)

# %%
history = model.fit(std_train, Y_train, validation_split=0.1, epochs=20)
# Out:
# Epoch 1/20
# 13/13 [==============================] - 1s 25ms/step - loss: 0.5276 - accuracy: 0.7188 - val_loss: 0.3104 - val_accuracy: 0.9783
# Epoch 2/20
# 13/13 [==============================] - 0s 3ms/step - loss: 0.2516 - accuracy: 0.9218 - val_loss: 0.1517 - val_accuracy: 0.9783
# Epoch 3/20
# 13/13 [==============================] - 0s 3ms/step - loss: 0.1454 - accuracy: 0.9438 - val_loss: 0.1076 - val_accuracy: 0.9783
# Epoch 4/20
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0998 - accuracy: 0.9682 - val_loss: 0.0796 - val_accuracy: 0.9783
# Epoch 5/20
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0754 - accuracy: 0.9829 - val_loss: 0.0790 - val_accuracy: 0.9565
# Epoch 6/20
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0655 - accuracy: 0.9853 - val_loss: 0.0670 - val_accuracy: 0.9565
# Epoch 7/20
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0599 - accuracy: 0.9878 - val_loss: 0.0640 - val_accuracy: 0.9565
# Epoch 8/20
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0493 - accuracy: 0.9878 - val_loss: 0.0626 - val_accuracy: 0.9565
# Epoch 9/20
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0459 - accuracy: 0.9902 - val_loss: 0.0628 - val_accuracy: 0.9783
# Epoch 10/20
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0409 - accuracy: 0.9902 - val_loss: 0.0603 - val_accuracy: 0.9565
# Epoch 11/20
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0419 - accuracy: 0.9927 - val_loss: 0.0635 - val_accuracy: 0.9348
# Epoch 12/20
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0337 - accuracy: 0.9878 - val_loss: 0.0604 - val_accuracy: 0.9565
# Epoch 13/20
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0289 - accuracy: 0.9927 - val_loss: 0.0584 - val_accuracy: 0.9565
# Epoch 14/20
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0256 - accuracy: 0.9927 - val_loss: 0.0586 - val_accuracy: 0.9348
# Epoch 15/20
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0221 - accuracy: 0.9927 - val_loss: 0.0572 - val_accuracy: 0.9565
# Epoch 16/20
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0195 - accuracy: 0.9951 - val_loss: 0.0627 - val_accuracy: 0.9565
# Epoch 17/20
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0180 - accuracy: 0.9927 - val_loss: 0.0656 - val_accuracy: 0.9565
# Epoch 18/20
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0149 - accuracy: 0.9951 - val_loss: 0.0651 - val_accuracy: 0.9565
# Epoch 19/20
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0131 - accuracy: 0.9976 - val_loss: 0.0691 - val_accuracy: 0.9565
# Epoch 20/20
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0111 - accuracy: 0.9976 - val_loss: 0.0704 - val_accuracy: 0.9565

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])

plt.title('Model Accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')

plt.legend(['training data','validation data'], loc = 'lower right')

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])

plt.title('Model Loss')
plt.ylabel('loss')
plt.xlabel('epoch')

plt.legend(['training data','validation data'], loc = 'lower right')

# %%
# Accuracy on test data
loss, accuracy = model.evaluate(std_test,Y_test)
# Out:
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1363 - accuracy: 0.9561

# %% [markdown]
# # Now the prediction part

# %%
m_predict =model.predict(std_test)
# Out:
# 4/4 [==============================] - 0s 1ms/step

# %%
print(m_predict[2])
# Out:
# [0.00576493 0.9968625 ]
